# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn

# %%
hee = pd.read_csv("Cars_Data.csv",index_col=0,na_values=["??","???"])

# %%
hot = hee.copy()

# %%
too = pd.read_csv("titanic_train.csv",index_col=0,na_values=["??","???"])

# %%
tot = too.copy()

# %%
tot.head(2)
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
#
#              SibSp  Parch     Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0  A/5 21171   7.2500   NaN        S
# 2                1      0   PC 17599  71.2833   C85        C

# %%
tot.dropna(axis=0,inplace= True)

# %%
tot.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 183 entries, 2 to 890
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  183 non-null    int64
#  1   Pclass    183 non-null    int64
#  2   Name      183 non-null    object
#  3   Sex       183 non-null    object
#  4   Age       183 non-null    float64
#  5   SibSp     183 non-null    int64
#  6   Parch     183 non-null    int64
#  7   Ticket    183 non-null    object
#  8   Fare      183 non-null    float64
#  9   Cabin     183 non-null    object
#  10  Embarked  183 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 17.2+ KB

# %%
hot.dropna(axis=0,inplace= True)
# we using the dropna function for deleting the missing value

# %% [markdown]
# # Scatter Plot diagram
# ### we use:
# - basic scatter plot using seaborn
# - add regression line or of/on regression plot
# - change the marker
# - using the three parameter or catagory in scatter plot

# %%
hot.head(2)
# Out:
#                 Model   Type Origin DriveTrain      MSRP   Invoice  \
# Make
# Acura             MDX    SUV   Asia        All  $36,945   $33,337
# Acura  RSX Type S 2dr  Sedan   Asia      Front  $23,820   $21,761
#
#        EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# Make
# Acura         3.5        6.0       265.0      17.0         23.0  4451.0
# Acura         2.0        4.0       200.0      24.0         31.0  2778.0
#
#        Wheelbase  Length
# Make
# Acura      106.0   189.0
# Acura      101.0   172.0

# %%
hoo = pd.read_csv("toyota.csv",index_col= 0,na_values=["??","???"])

# %%
hot = hoo.copy()

# %%
hot.count()
# Out:
# year            6738
# price           6738
# transmission    6738
# mileage         6738
# fuelType        6738
# tax             6738
# mpg             6738
# engineSize      6738
# dtype: int64

# %%
hot.head(2)
# Out:
#        year  price transmission  mileage fuelType  tax   mpg  engineSize
# model
#  GT86  2016  16000       Manual    24089   Petrol  265  36.2         2.0
#  GT86  2017  15995       Manual    18615   Petrol  145  36.2         2.0

# %%
### delete missing value
hot.dropna(axis=0,inplace=True)

# %%
hot.count()
# Out:
# year            6738
# price           6738
# transmission    6738
# mileage         6738
# fuelType        6738
# tax             6738
# mpg             6738
# engineSize      6738
# dtype: int64

# %% [markdown]
# ## Basic scatter plot using seaborn
# - I want to show you the relation between the mileage and price using the scatter plot in seaborn

# %%
sn.regplot(x=hot["mileage"],y=hot["price"])
# Out:
# <AxesSubplot: xlabel='mileage', ylabel='price'>

# %% [markdown]
# ## Regression Line
# - we can on or off that line using the fit_reg = False,
# - by default it's on

# %%
sn.regplot(x=hot["mileage"],y=hot["price"],fit_reg=False)
# Out:
# <AxesSubplot: xlabel='mileage', ylabel='price'>

# %% [markdown]
# ## marker
# - in this point we want to change the scatter plot marker
# - for this we use the marker parameter

# %%
sn.regplot(x=hot["mileage"],y=hot["price"],marker= "*",color="teal")
# Out:
# <AxesSubplot: xlabel='mileage', ylabel='price'>

# %%
hot.head(10)
# Out:
#        year  price transmission  mileage fuelType  tax   mpg  engineSize
# model
#  GT86  2016  16000       Manual    24089   Petrol  265  36.2         2.0
#  GT86  2017  15995       Manual    18615   Petrol  145  36.2         2.0
#  GT86  2015  13998       Manual    27469   Petrol  265  36.2         2.0
#  GT86  2017  18998       Manual    14736   Petrol  150  36.2         2.0
#  GT86  2017  17498       Manual    36284   Petrol  145  36.2         2.0
#  GT86  2017  15998       Manual    26919   Petrol  260  36.2         2.0
#  GT86  2017  18522       Manual    10456   Petrol  145  36.2         2.0
#  GT86  2017  18995       Manual    12340   Petrol  145  36.2         2.0
#  GT86  2020  27998       Manual      516   Petrol  150  33.2         2.0
#  GT86  2016  13990       Manual    37999   Petrol  265  36.2         2.0

# %% [markdown]
# # Implot Diagram
# - if we need to show more than tow parameter in our diagram,we can use this Method
# ### this diagram have:
# - data = which we can spesify our dataset
# - fit_reg
# - hua = we can add another columns
# - legend = for spesify the columns in diagram
# - pallete = we can use teh set of color in seaborn

# %%
sn.lmplot(x="mileage",
y="price",
data=hot,
fit_reg=False,
hue="fuelType",
legend=True,
palette="Set1")

# %%
sn.lmplot(x="mileage",
y="price",
data=hot,
fit_reg=False,
hue="year",
legend=True,
palette="Set1")

# %%
sn.lmplot(x="mileage",
y="price",
data=hot,
fit_reg=False,
hue="transmission",
legend=True,
palette="Set1")

# %%
tot.head(2)
# Out:
#              Survived  Pclass  \
# PassengerId
# 2                   1       1
# 4                   1       1
#
#                                                           Name     Sex   Age  \
# PassengerId
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
#
#              SibSp  Parch    Ticket     Fare Cabin Embarked
# PassengerId
# 2                1      0  PC 17599  71.2833   C85        C
# 4                1      0    113803  53.1000  C123        S

# %%
sn.lmplot(x="Fare",
y="Age",
data=tot,
# fit_reg=False,
hue="Survived",
legend=True,
palette="Set1")

# %% [markdown]
# # Histogram Diagram
# - we use distplot method for this diagram in seaborn

# %%
tot.head(2)
# Out:
#              Survived  Pclass  \
# PassengerId
# 2                   1       1
# 4                   1       1
#
#                                                           Name     Sex   Age  \
# PassengerId
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
#
#              SibSp  Parch    Ticket     Fare Cabin Embarked
# PassengerId
# 2                1      0  PC 17599  71.2833   C85        C
# 4                1      0    113803  53.1000  C123        S

# %% [markdown]
# #### Age ditribution using Seaborn
# - I want to show you the age in the seaborn diagram

# %%
sn.distplot(tot["Age"])
# Out:
# C:\Users\Computer House\AppData\Local\Temp\ipykernel_1916\468748432.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(tot["Age"])
# <AxesSubplot: xlabel='Age', ylabel='Density'>

# %% [markdown]
# #### read the answer of previous line
# - seaborn use instead of distplot another function namaly histplot

# %%
sn.histplot(tot["Age"])
# Out:
# <AxesSubplot: xlabel='Age', ylabel='Count'>

# %% [markdown]
# ### displot
# - or we can use displot instead of distplot

# %%
sn.displot(tot["Age"])

# %% [markdown]
# ### density estimite Line
# - we add another property namaly kde,
# - kde have to value True,False

# %%
sn.displot(tot["Age"],kde =True)

# %% [markdown]
# ### bins
# - for control the number of bins we add another property namaly,bins

# %%
sn.displot(tot["Age"],color="teal",kde=True,bins=8)

# %% [markdown]
# # Bar plot
# - for using the bar plot we use the countplot method

# %%
too=pd.read_csv("toyota.csv",index_col=0,na_values=["??","???"])
too.dropna(inplace=True, axis=0)
tot= too.copy()
tot.head(2)
# Out:
#        year  price transmission  mileage fuelType  tax   mpg  engineSize
# model
#  GT86  2016  16000       Manual    24089   Petrol  265  36.2         2.0
#  GT86  2017  15995       Manual    18615   Petrol  145  36.2         2.0

# %% [markdown]
# ### fuelType diagram
# - I want to show you the diagram of fuelType using seaborn bar plot

# %%
sn.countplot(x="fuelType",data=tot,palette="Set2")
# Out:
# <AxesSubplot: xlabel='fuelType', ylabel='count'>

# %% [markdown]
# ## Grouped Bar plot
# - for that which we add another dolumn in our daiagram and show it,we add another property namaly hue
# - in below I want to show you the fuelType and transmission diagram
# - first I am use the crosstab to show the data that I represent in diagram

# %%
pd.crosstab(index= tot['fuelType'],
            columns=tot['transmission'],
            dropna=True)
# Out:
# transmission  Automatic  Manual  Other  Semi-Auto
# fuelType
# Diesel               97     378      0         28
# Hybrid             2038       4      1          0
# Other               100       5      0          0
# Petrol              422    3439      0        226

# %% [markdown]
# ### diagram of the above

# %%
sn.countplot(x="fuelType",data=tot,palette="Set2",hue="transmission")
# Out:
# <AxesSubplot: xlabel='fuelType', ylabel='count'>

# %% [markdown]
# # Box and Wiskers plot
# - it's good for namerical data
# - it's good for is good for chaiking the namerical and catagory data.

# %%
tot.head(2
         )
# Out:
#        year  price transmission  mileage fuelType  tax   mpg  engineSize
# model
#  GT86  2016  16000       Manual    24089   Petrol  265  36.2         2.0
#  GT86  2017  15995       Manual    18615   Petrol  145  36.2         2.0

# %% [markdown]
# in the below i want to show you the fuelType diagram

# %%
sn.boxplot(y=tot["price"])
# Out:
# <AxesSubplot: ylabel='price'>

# %% [markdown]
# ### we can use the boxplot for checking the namerical and catagorical data
# - in below I want to show you the distribution of fuelType and price
# - but first the I want to show you the data I will represent it.

# %%
pd.crosstab(index=tot["price"],columns=tot["fuelType"],dropna=True)
# Out:
# fuelType  Diesel  Hybrid  Other  Petrol
# price
# 850            1       0      0       0
# 899            0       0      0       1
# 950            0       0      0       1
# 975            0       0      0       1
# 1200           0       0      0       1
# ...          ...     ...    ...     ...
# 52291          1       0      0       0
# 52990          1       0      0       0
# 54550          1       0      0       0
# 54991          1       0      0       0
# 59995          0       0      1       0
#
# [2114 rows x 4 columns]

# %%
sn.boxplot(y=tot["price"], x=tot["fuelType"])
# Out:
# <AxesSubplot: xlabel='fuelType', ylabel='price'>

# %% [markdown]
# ## Grouped box plot whiskers plot
# - in this point I want to show you the price,fuelType and transmission

# %%
sn.boxplot(x="fuelType",y=tot["price"],hue="transmission",data=tot)
# Out:
# <AxesSubplot: xlabel='fuelType', ylabel='price'>

# %% [markdown]
# ## Box-whiskers and histogram plot

# %%
too=pd.read_csv("toyota.csv",index_col= 0,na_values=["??","???"])
tot = too.copy()
tot.head(2)
# Out:
#        year  price transmission  mileage fuelType  tax   mpg  engineSize
# model
#  GT86  2016  16000       Manual    24089   Petrol  265  36.2         2.0
#  GT86  2017  15995       Manual    18615   Petrol  145  36.2         2.0

# %%
# f,(ax_box,ax_hist)=plt.subplot(2,gridspec_kw={"height_ratios":(.15,.85,)})
# sn.boxplot(tot["price"],ax=ax_box)
# sn.displot(tot["price"],ax=ax_hist,kde=False)
